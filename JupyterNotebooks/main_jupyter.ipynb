# %%
import geemap
import ee

# %%
import PP, Baseline

# %%
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=eEp4b8Ulfy-6ZBw0v5fqIwaUc4r97bUY1LR37gg3FZQ&tc=Wrx-lHQPvPIp_yI3SEzxFRhnUlSVw0jGubOqL5VzeNY&cc=zolSURcvxLDZ_jHZNkEGqrbBZbZMICFh83tt13FlbjE>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=eEp4b8Ulfy-6ZBw0v5fqIwaUc4r97bUY1LR37gg3FZQ&tc=Wrx-lHQPvPIp_yI3SEzxFRhnUlSVw0jGubOqL5VzeNY&cc=zolSURcvxLDZ_jHZNkEGqrbBZbZMICFh83tt13FlbjE</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1ATX87lNHdXIxGIQZj032ihok2Oc37BVc4xyfHbThtSdidPRjURhdzrPD6HE
#
# ...

# %%
#Please change this file to be the shapefile of choice.
aoi = geemap.shp_to_ee('VCS2250/Calyx_VCS_2250_project.shp')

# %%
#Run this line to print Hectares of aoi covered by DEFINED Protected Planet zones.
print(PP.ProtectedPlanetHectares(aoi))
# Out:
# 179861.4780498678

# %%
#Run this line to print % of aoi covered by Protected Planet zones.
print('Percentage of total: ' + str(PP.ProtectedPlanetPercent(aoi)) + '%.')
# Out:
# Percentage of total: 34.72055785257141%.

# %%
#ORDER OF OPERATIONS!
# Also output individual copernicus raw data and DEM .tif file, diff layer of area below certain meters in DEM. Very easy!
